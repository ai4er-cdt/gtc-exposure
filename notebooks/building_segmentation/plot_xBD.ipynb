# %% [markdown]
# # Creating model from the xBD dataset

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
loc = 'palu-tsunami_00000020'
imgloc = '/home/jovyan/xBD/train/images/'+loc
tgtloc = '/home/jovyan/xBD/train/targets/'+loc
pre = mpimg.imread(imgloc+'_pre_disaster.png')
post = mpimg.imread(imgloc+'_post_disaster.png')
preTarget = mpimg.imread(tgtloc+'_pre_disaster_target.png')
postTarget = mpimg.imread(tgtloc+'_post_disaster_target.png')
fig, ax = plt.subplots(2,2, figsize=(10,10))
ax[0,0].imshow(pre)
ax[0,0].title.set_text('Pre-event image')
ax[0,1].imshow(post)
ax[0,1].title.set_text('Post-event image')
ax[1,0].imshow(preTarget)
ax[1,0].title.set_text('Pre-event targets')
ax[1,1].imshow(postTarget)
ax[1,1].title.set_text('Post-event targets')
fig.suptitle(loc)
plt.show()

# %%
import json
with open("/home/jovyan/xBD/train/labels/"+loc+'_post_disaster.json') as f:
    fc = json.load(f)

# %%
import numpy as np
color_dict = {'Not Applicable':'green','Negligible to slight damage':'blue', 'Moderately Damaged':'yellow', 'Highly Damaged':'orange', 'Completely Destroyed':'red'}
for i in range(len(fc['features']['lng_lat'])):
    try:
        vals = np.array(fc['features']['lng_lat'][i]['wkt'])
        print(vals)
    except Exception:
        pass
    plt.plot(vals[:,0],vals[:,1],color=color_dict[fc['features']['lng_lat'][i]['properties']['subtype']])
# Out:
# POLYGON ((119.8816037675395 -0.813852287222963, 119.8816358959385 -0.8139706009509754, 119.8813749662725 -0.8140047726646558, 119.880818784772 -0.8140051728544967, 119.8808038061472 -0.8139595101381912, 119.8808049103207 -0.8138565357466014, 119.8808046539883 -0.8138558421061526, 119.8816080952174 -0.8137481466794808, 119.8816037675395 -0.813852287222963))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-651a06336285> in <module>
#       7     except Exception:
#       8         pass
# ----> 9     plt.plot(vals[:,0],vals[:,1],color=color_dict[fc['features']['lng_lat'][i]['properties']['subtype']])
#
# IndexError: too many indices for array

# %%
fc['features']['lng_lat'][0]['properties']
# Out:
# {'feature_type': 'building',
#  'subtype': 'no-damage',
#  'uid': 'fe34d2f7-c9fe-41a3-8abc-fb2a23cc1d81'}

# %%
len(fc['features']['lng_lat'])
# Out:
# 87
