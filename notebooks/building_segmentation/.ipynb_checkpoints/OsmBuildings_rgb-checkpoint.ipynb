# %% [markdown]
# ## Train Classifier to recognise buildings from Sentinel rgb imagery
#
# ### 1 - Import and display training building footprints

# %%
# Import packages - Needs utils.py and unet.py in current directory
import IPython
import ipywidgets
import ipyleaflet
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import numpy as np
import random
import os
import tensorflow as tf

import descarteslabs as dl
import descarteslabs.workflows as wf
from descarteslabs.vectors import FeatureCollection, properties as p

from utils import make_ground_dataset_from_polygons, get_center_location
from unet import UNet

# %%
# Import Geojson - to FeatureCollection?
with open("/home/jovyan/OSM_data/sanFranBuildings.geojson") as f:
    fc = json.load(f)
print('Number of buildings:', len(fc['features']))
# Out:
# Number of buildings: 5758

# %% [markdown]
# ### 2 - Get corresponding imagery for building footprints

# %%
# Get corresponding imagery for all polygons
n_samples = make_ground_dataset_from_polygons('/home/jovyan/OSM_data/sanFranBuildings.geojson',
                                              products='sentinel-2:L1C',
                                              bands=['red green blue'],
                                              resolution=10,
                                              tilesize=64,
                                              pad=0,
                                              start_datetime='2021-01-06',
                                              end_datetime='2021-01-11',
                                              out_file='sanfranrgb.tfrecords')
# Out:
# WARNING: Some exceptions were caught while getting dltiles-2s
# Caught exception for lat: 37.78498996185687 and lon: -122.41415961046533 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623E850> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78498996185687 and lon: -122.41415961046533 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D08D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78498996185687 and lon: -122.41415961046533 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.776539140402136 and lon: -122.420812123096 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.776539140402136 and lon: -122.420812123096 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.776539140402136 and lon: -122.420812123096 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.768981208975106 and lon: -122.42387479246015 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.768981208975106 and lon: -122.42387479246015 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.768981208975106 and lon: -122.42387479246015 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.766675993600735 and lon: -122.41635458326375 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.766675993600735 and lon: -122.41635458326375 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76665272281533 and lon: -122.4167795421318 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF862349D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.76665272281533 and lon: -122.4167795421318 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E6E50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.76665272281533 and lon: -122.4167795421318 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861A8DD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.766482090591445 and lon: -122.41731405512883 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EBE90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.766482090591445 and lon: -122.41731405512883 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.766482090591445 and lon: -122.41731405512883 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7834092112945 and lon: -122.42626697772278 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7834092112945 and lon: -122.42626697772278 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7834092112945 and lon: -122.42626697772278 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78378495538543 and lon: -122.4268808666009 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86234A10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78378495538543 and lon: -122.4268808666009 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861F1250> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78378495538543 and lon: -122.4268808666009 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861C3610> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78371786551506 and lon: -122.42740221323906 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78371786551506 and lon: -122.42740221323906 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78371786551506 and lon: -122.42740221323906 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861A4390> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78327565926016 and lon: -122.42731493291286 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78327565926016 and lon: -122.42731493291286 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78327565926016 and lon: -122.42731493291286 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.776081863748736 and lon: -122.40297547819472 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.776081863748736 and lon: -122.40297547819472 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.776081863748736 and lon: -122.40297547819472 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78553353659387 and lon: -122.42730474060953 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78553353659387 and lon: -122.42730474060953 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78553353659387 and lon: -122.42730474060953 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78258901583956 and lon: -122.42860563867333 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78258901583956 and lon: -122.42860563867333 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78258901583956 and lon: -122.42860563867333 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787504508614575 and lon: -122.42780074112717 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787504508614575 and lon: -122.42780074112717 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E16D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787504508614575 and lon: -122.42780074112717 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861945D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.786912122711385 and lon: -122.42465267628414 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D3E90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78239686114935 and lon: -122.42654588761823 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861CD450> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78239686114935 and lon: -122.42654588761823 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8614FAD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78239686114935 and lon: -122.42654588761823 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861F7C10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78234185226305 and lon: -122.42697305845326 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E6290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78234185226305 and lon: -122.42697305845326 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E1C10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78234185226305 and lon: -122.42697305845326 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86234A10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.782418069644095 and lon: -122.42637900819952 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861F7E10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.782364438496344 and lon: -122.4268023139044 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.782364438496344 and lon: -122.4268023139044 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.782364438496344 and lon: -122.4268023139044 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861A4B50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77828538111019 and lon: -122.42357692067165 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DA890> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77828538111019 and lon: -122.42357692067165 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EB510> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77555556851004 and lon: -122.42797737087605 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77555556851004 and lon: -122.42797737087605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86219A50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77555556851004 and lon: -122.42797737087605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF877033D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77525824368722 and lon: -122.42358752377157 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77525824368722 and lon: -122.42358752377157 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77525824368722 and lon: -122.42358752377157 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78433191027757 and lon: -122.4116944578785 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78433191027757 and lon: -122.4116944578785 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787957902920205 and lon: -122.401929805866 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77886274882305 and lon: -122.4026670132451 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77886274882305 and lon: -122.4026670132451 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77886274882305 and lon: -122.4026670132451 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.779467159100854 and lon: -122.41044704222107 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.779467159100854 and lon: -122.41044704222107 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.779467159100854 and lon: -122.41044704222107 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77656041606387 and lon: -122.41470302784981 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77656041606387 and lon: -122.41470302784981 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77656041606387 and lon: -122.41470302784981 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.767682913169914 and lon: -122.41011666771251 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.784044331879144 and lon: -122.4139503563394 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.784044331879144 and lon: -122.4139503563394 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.784044331879144 and lon: -122.4139503563394 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.767973787144804 and lon: -122.40024383970119 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77197843422897 and lon: -122.4220984220869 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D6250> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7831055014332 and lon: -122.40404878501879 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7831055014332 and lon: -122.40404878501879 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861AFAD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7831055014332 and lon: -122.40404878501879 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86237450> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.784228298678144 and lon: -122.40318457420591 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EB750> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.784228298678144 and lon: -122.40318457420591 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861CD410> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.784228298678144 and lon: -122.40318457420591 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86154590> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78470570950785 and lon: -122.39937299855556 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861B0910> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78470570950785 and lon: -122.39937299855556 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86141D10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78470570950785 and lon: -122.39937299855556 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D0550> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.785598942150045 and lon: -122.40206596730447 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86151D90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.785598942150045 and lon: -122.40206596730447 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E23D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.785598942150045 and lon: -122.40206596730447 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DB350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78022721579154 and lon: -122.41601868474929 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DE7D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78215175903416 and lon: -122.40049559742224 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78215175903416 and lon: -122.40049559742224 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78215175903416 and lon: -122.40049559742224 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78237336025864 and lon: -122.40521355532438 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.786991301890524 and lon: -122.40596917384215 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.786991301890524 and lon: -122.40596917384215 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.786991301890524 and lon: -122.40596917384215 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.782728248416724 and lon: -122.40723803313237 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.782728248416724 and lon: -122.40723803313237 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.782728248416724 and lon: -122.40723803313237 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.779444616212835 and lon: -122.4123347044125 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.779444616212835 and lon: -122.4123347044125 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.779444616212835 and lon: -122.4123347044125 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77923085 and lon: -122.41131459999997 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77923085 and lon: -122.41131459999997 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77923085 and lon: -122.41131459999997 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.781890202913246 and lon: -122.411345775945 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77761386748765 and lon: -122.42058642480042 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861AB5D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77761386748765 and lon: -122.42058642480042 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86154C50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77761386748765 and lon: -122.42058642480042 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D0BD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78520489372423 and lon: -122.40836752813664 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EFBD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78520489372423 and lon: -122.40836752813664 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8610A390> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78520489372423 and lon: -122.40836752813664 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86151450> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78561869850937 and lon: -122.40815802225355 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86113990> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78561869850937 and lon: -122.40815802225355 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86103890> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78561869850937 and lon: -122.40815802225355 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86234D50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777903636081206 and lon: -122.4119944093846 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623A290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777903636081206 and lon: -122.4119944093846 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.777903636081206 and lon: -122.4119944093846 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78592931803041 and lon: -122.41732327436743 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86231D90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78592931803041 and lon: -122.41732327436743 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8617A250> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78592931803041 and lon: -122.41732327436743 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615D810> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78580265342741 and lon: -122.41774819555704 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86194710> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78580265342741 and lon: -122.41774819555704 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86187690> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78580265342741 and lon: -122.41774819555704 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EFC10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.785594051478725 and lon: -122.42006056869945 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861CA510> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.785594051478725 and lon: -122.42006056869945 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86113F10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.785594051478725 and lon: -122.42006056869945 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86231A90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78685080973921 and lon: -122.41440202245582 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78685080973921 and lon: -122.41440202245582 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623EC10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78685080973921 and lon: -122.41440202245582 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E2F50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78676466350435 and lon: -122.41463472506987 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623A550> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78676466350435 and lon: -122.41463472506987 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86157050> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78676466350435 and lon: -122.41463472506987 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EFF90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78696031216754 and lon: -122.4129861984426 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861E20D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78696031216754 and lon: -122.4129861984426 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861A4310> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78696031216754 and lon: -122.4129861984426 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623E690> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78709266898515 and lon: -122.41254141854026 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D01D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78709266898515 and lon: -122.41254141854026 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DB4D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78709266898515 and lon: -122.41254141854026 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861C3790> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787171347866135 and lon: -122.4129043943022 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861AB610> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787171347866135 and lon: -122.4129043943022 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615A090> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787171347866135 and lon: -122.4129043943022 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86151550> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78752570000001 and lon: -122.41308014999998 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86231690> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78752570000001 and lon: -122.41308014999998 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861B0E10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78752570000001 and lon: -122.41308014999998 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86108510> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78734200351192 and lon: -122.41301869878264 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615FB90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78734200351192 and lon: -122.41301869878264 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86113E50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78734200351192 and lon: -122.41301869878264 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86103BD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787585240325924 and lon: -122.41236502037312 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787585240325924 and lon: -122.41236502037312 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787585240325924 and lon: -122.41236502037312 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78745650672898 and lon: -122.41188429905505 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78745650672898 and lon: -122.41188429905505 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78745650672898 and lon: -122.41188429905505 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787426749999995 and lon: -122.41213409999999 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787426749999995 and lon: -122.41213409999999 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787426749999995 and lon: -122.41213409999999 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.787306927467384 and lon: -122.41015593906762 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7871205777768 and lon: -122.40846463858234 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7871205777768 and lon: -122.40846463858234 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7871205777768 and lon: -122.40846463858234 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78699013590754 and lon: -122.40903808095804 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8619ECD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.786016844307255 and lon: -122.40829652140704 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8610CF50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78580573164385 and lon: -122.40819632502203 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86181390> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78367497229003 and lon: -122.41291871437205 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8621F7D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78367497229003 and lon: -122.41291871437205 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8619E910> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78367497229003 and lon: -122.41291871437205 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861F1FD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77601333764483 and lon: -122.41896273466041 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86106910> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.778654312071204 and lon: -122.41528983288624 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778654312071204 and lon: -122.41528983288624 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778654312071204 and lon: -122.41528983288624 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77859318160563 and lon: -122.41545263542896 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77859318160563 and lon: -122.41545263542896 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77859318160563 and lon: -122.41545263542896 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778532929392775 and lon: -122.41562237734321 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778532929392775 and lon: -122.41562237734321 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778532929392775 and lon: -122.41562237734321 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861CAFD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77935057933885 and lon: -122.41466638134914 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86137250> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77935057933885 and lon: -122.41466638134914 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8612C350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77935057933885 and lon: -122.41466638134914 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861186D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.779993245339455 and lon: -122.41100714625792 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861347D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.779993245339455 and lon: -122.41100714625792 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8616DE10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.779993245339455 and lon: -122.41100714625792 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8619E150> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7830993758208 and lon: -122.4066265197245 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86187190> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7830993758208 and lon: -122.4066265197245 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86109550> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7830993758208 and lon: -122.4066265197245 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615EC50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78321914374979 and lon: -122.40647442960093 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DEB50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78321914374979 and lon: -122.40647442960093 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF862373D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78321914374979 and lon: -122.40647442960093 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86157090> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78115440219352 and lon: -122.40790044726721 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D0850> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78115440219352 and lon: -122.40790044726721 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861BE610> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78115440219352 and lon: -122.40790044726721 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861A8FD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.780226734631256 and lon: -122.40908723298446 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615FB90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.780226734631256 and lon: -122.40908723298446 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8610E850> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.780226734631256 and lon: -122.40908723298446 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86194DD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78116527403936 and lon: -122.40627467882007 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EFCD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78116527403936 and lon: -122.40627467882007 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86128B90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78714866696068 and lon: -122.40793448394051 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86234350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78714866696068 and lon: -122.40793448394051 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623EE90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78714866696068 and lon: -122.40793448394051 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615EED0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78699576808877 and lon: -122.40790253730786 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86103050> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78699576808877 and lon: -122.40790253730786 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EF410> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78699576808877 and lon: -122.40790253730786 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86103650> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78687980673374 and lon: -122.40786743983183 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861A8D50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78687980673374 and lon: -122.40786743983183 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8623EB90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78687980673374 and lon: -122.40786743983183 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861370D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78679544953195 and lon: -122.40784991388742 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86118450> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78679544953195 and lon: -122.40784991388742 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78679544953195 and lon: -122.40784991388742 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861D3750> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.786649749999995 and lon: -122.40791325000001 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.786649749999995 and lon: -122.40791325000001 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DB4D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77696976520768 and lon: -122.41424274322009 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF862343D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.778138601819144 and lon: -122.41866650579043 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DB4D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.778138601819144 and lon: -122.41866650579043 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861C3590> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.778138601819144 and lon: -122.41866650579043 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86128B90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77767219719411 and lon: -122.41888092223279 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77767219719411 and lon: -122.41888092223279 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77767219719411 and lon: -122.41888092223279 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778126400000005 and lon: -122.41945744999998 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778126400000005 and lon: -122.41945744999998 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778126400000005 and lon: -122.41945744999998 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7779982 and lon: -122.41943185000001 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7779982 and lon: -122.41943185000001 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.777900280916285 and lon: -122.41941220501414 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86151510> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777900280916285 and lon: -122.41941220501414 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861559D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777900280916285 and lon: -122.41941220501414 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8610EE50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777417287185344 and lon: -122.41711918960385 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861377D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777417287185344 and lon: -122.41711918960385 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860DDA50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777417287185344 and lon: -122.41711918960385 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86119590> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777114764815146 and lon: -122.41511104087208 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860E4410> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777114764815146 and lon: -122.41511104087208 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860DE250> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.777114764815146 and lon: -122.41511104087208 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78103508141732 and lon: -122.41791347178842 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8616D790> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78103508141732 and lon: -122.41791347178842 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86134290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78103508141732 and lon: -122.41791347178842 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860DE490> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78374968132291 and lon: -122.4119707402235 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860FB3D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78374968132291 and lon: -122.4119707402235 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860EDE50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78374968132291 and lon: -122.4119707402235 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8617A290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77798534393631 and lon: -122.41622792906757 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861089D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77798534393631 and lon: -122.41622792906757 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDFB4746F90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77798534393631 and lon: -122.41622792906757 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86103750> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77811704157183 and lon: -122.41607391882488 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861B0A90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77811704157183 and lon: -122.41607391882488 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8615B0D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77811704157183 and lon: -122.41607391882488 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8610A190> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.778311160565096 and lon: -122.41607186700786 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860E3510> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.778311160565096 and lon: -122.41607186700786 - Could not find client_id
# Caught exception for lat: 37.778311160565096 and lon: -122.41607186700786 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778299880080354 and lon: -122.41581192117576 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778299880080354 and lon: -122.41581192117576 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.778299880080354 and lon: -122.41581192117576 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78612161655735 and lon: -122.40599286380258 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78612161655735 and lon: -122.40599286380258 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78612161655735 and lon: -122.40599286380258 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76710514597671 and lon: -122.41115789691105 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78008338982795 and lon: -122.4123935926149 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78008338982795 and lon: -122.4123935926149 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78008338982795 and lon: -122.4123935926149 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77838680806726 and lon: -122.41156804428607 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77838680806726 and lon: -122.41156804428607 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86154AD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.77838680806726 and lon: -122.41156804428607 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860ED390> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78137842592401 and lon: -122.41243609269517 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EEE10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78137842592401 and lon: -122.41243609269517 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86137F50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78137842592401 and lon: -122.41243609269517 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86155350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.781696783877294 and lon: -122.41337760456446 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.781696783877294 and lon: -122.41337760456446 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.781696783877294 and lon: -122.41337760456446 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.781851409305126 and lon: -122.41254841395154 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86155C10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.781851409305126 and lon: -122.41254841395154 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86088510> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.781851409305126 and lon: -122.41254841395154 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860D9A10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78537540000001 and lon: -122.4184418 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EE690> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78253187787786 and lon: -122.41833649522917 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860D79D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78253187787786 and lon: -122.41833649522917 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861B0990> has type TiffImageFile, but expected one of: int, long, float
# ...
# Caught exception for lat: 37.7870419 and lon: -122.4232244 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860E4590> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7870419 and lon: -122.4232244 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86233B10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7706203 and lon: -122.4199394 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B6E650> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7706203 and lon: -122.4199394 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85C85110> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7706203 and lon: -122.4199394 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B9CFD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7708417 and lon: -122.4207906 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7716363 and lon: -122.4141387 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7716363 and lon: -122.4141387 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7716363 and lon: -122.4141387 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7710869 and lon: -122.4104749 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7710869 and lon: -122.4104749 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7710869 and lon: -122.4104749 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7761599 and lon: -122.4172795 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7761599 and lon: -122.4172795 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7779807 and lon: -122.4211034 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7779807 and lon: -122.4211034 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7780409 and lon: -122.4130438 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7780409 and lon: -122.4130438 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7780409 and lon: -122.4130438 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.769458 and lon: -122.4032877 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.769458 and lon: -122.4032877 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.769458 and lon: -122.4032877 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861BEED0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7690411 and lon: -122.4032399 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8612F910> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7690411 and lon: -122.4032399 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86178350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7690411 and lon: -122.4032399 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A701D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7726256 and lon: -122.397605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B78390> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7726256 and lon: -122.397605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85C33F90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7721721 and lon: -122.3968768 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85C33DD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7721721 and lon: -122.3968768 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85CBEB10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7721721 and lon: -122.3968768 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861CDDD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7728851 and lon: -122.3968625 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861DA3D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7728851 and lon: -122.3968625 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85C053D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7728851 and lon: -122.3968625 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B33910> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7805472 and lon: -122.4178016 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7805472 and lon: -122.4178016 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7805472 and lon: -122.4178016 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7782912 and lon: -122.4129353 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7782912 and lon: -122.4129353 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7782912 and lon: -122.4129353 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7786706 and lon: -122.4132344 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7786706 and lon: -122.4132344 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7786706 and lon: -122.4132344 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85D1D090> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7801321 and lon: -122.4144169 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85AF0BD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7801321 and lon: -122.4144169 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85AB4290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7801321 and lon: -122.4144169 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF862310D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7797309 and lon: -122.4137013 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85BCC7D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7797309 and lon: -122.4137013 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B78290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7797309 and lon: -122.4137013 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7842374 and lon: -122.4083843 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7842374 and lon: -122.4083843 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85AACA90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7842374 and lon: -122.4083843 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86077190> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7843029 and lon: -122.4083016 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8604D450> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.786364 and lon: -122.4153431 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85CD8FD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.786364 and lon: -122.4153431 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.786364 and lon: -122.4153431 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7836797 and lon: -122.4055064 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7836797 and lon: -122.4055064 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7792557 and lon: -122.4041206 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85BD7A90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7792557 and lon: -122.4041206 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85CB1890> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7864304 and lon: -122.4072135 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7864304 and lon: -122.4072135 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A48190> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7864304 and lon: -122.4072135 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861EE350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7854849 and lon: -122.4063828 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86141410> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7854849 and lon: -122.4063828 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B5EA50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7854849 and lon: -122.4063828 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A6B490> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7855727 and lon: -122.4024296 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A86E90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7855727 and lon: -122.4024296 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85BB0A50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7855727 and lon: -122.4024296 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86160890> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7853003 and lon: -122.4021969 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF860A4A10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7853003 and lon: -122.4021969 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF861C5D10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7853003 and lon: -122.4021969 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A59C10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7866661 and lon: -122.4070054 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85AD9A90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7866661 and lon: -122.4070054 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B29210> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7866661 and lon: -122.4070054 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86105910> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7852013 and lon: -122.4068095 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85BE7550> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7852013 and lon: -122.4068095 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7850158 and lon: -122.4065741 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7871143 and lon: -122.4021498 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85CBE450> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7871143 and lon: -122.4021498 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A70690> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7871143 and lon: -122.4021498 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86077E90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7873974 and lon: -122.4024983 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85C053D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7873974 and lon: -122.4024983 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A5C850> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7873974 and lon: -122.4024983 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B23A10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787197 and lon: -122.4000605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85A6BC50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787197 and lon: -122.4000605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B92550> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.787197 and lon: -122.4000605 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85D208D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7856769 and lon: -122.3999252 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF86233C10> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7856769 and lon: -122.3999252 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF8611E5D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7856769 and lon: -122.3999252 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7848494 and lon: -122.3998061 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7848494 and lon: -122.3998061 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7848494 and lon: -122.3998061 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7713879 and lon: -122.3942142 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7713879 and lon: -122.3942142 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7713879 and lon: -122.3942142 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7788314 and lon: -122.3945313 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7788314 and lon: -122.3945313 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.7788314 and lon: -122.3945313 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7FDF85B5EE50> has type TiffImageFile, but expected one of: int, long, float

# %%
# Define the features in the TFRecords file
features = {
    'image/image_data': tf.io.FixedLenSequenceFeature([], dtype=tf.float32, allow_missing=True),
    'image/height': tf.io.FixedLenFeature([], tf.int64),
    'image/width': tf.io.FixedLenFeature([], tf.int64),
    'image/channels': tf.io.FixedLenFeature([], tf.int64),
    'target/target_data': tf.io.FixedLenSequenceFeature([], dtype=tf.float32, allow_missing=True),
    'target/height': tf.io.FixedLenFeature([], tf.int64),
    'target/width': tf.io.FixedLenFeature([], tf.int64),
    'target/channels': tf.io.FixedLenFeature([], tf.int64),
    'dltile': tf.io.FixedLenFeature([], tf.string)
}

# %%
def parse_example(example_proto):
    image_features = tf.io.parse_single_example(example_proto, features)
    
    img_height = tf.cast(image_features['image/height'], tf.int32)
    img_width = tf.cast(image_features['image/width'], tf.int32)
    img_channels = tf.cast(image_features['image/channels'], tf.int32)
    
    target_height = tf.cast(image_features['target/height'], tf.int32)
    target_width = tf.cast(image_features['target/width'], tf.int32)
    target_channels = tf.cast(image_features['target/channels'], tf.int32)
    
    image_raw = tf.reshape(tf.squeeze(image_features['image/image_data']),
                           tf.stack([img_height, img_width, img_channels]))
    
    target_raw = tf.reshape(tf.squeeze(image_features['target/target_data']),
                            tf.stack([target_height, target_width, target_channels]))
    
    return image_raw, target_raw

# %%
# Create a TFRecordDataset to read images from these TFRecords
data = tf.data.TFRecordDataset('/home/jovyan/OSM_data/sanfranrgb.tfrecords') \
           .map(parse_example, num_parallel_calls=4)

data_viz = iter(data.batch(1))

# %%
# Visualize samples. You can re-run this cell to iterate through the dataset.
img, trg = next(data_viz)
fig, ax = plt.subplots(1,2, figsize=(8,5))
ax[0].imshow(img.numpy().astype(np.uint8)[0])
ax[1].imshow(trg.numpy().astype(np.uint8)[0].squeeze())

# %% [markdown]
# ### 3 - Train Classifier

# %%
# Build the model. We could just use the base_model but then the input size would be fixed
# once we load a saved model. In order to be able to predict on larger tiles we create an
# input layer with no fixed size
base_model = UNet()
inputs = tf.keras.layers.Input(shape=(None, None, 3))
model = tf.keras.Model(inputs=inputs, outputs=base_model(inputs))

# %%
# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# u_net (UNet)                 (None, None, None, 1)     7760097
# =================================================================
# Total params: 7,760,097
# Trainable params: 7,760,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define some transforms
def subtract_mean(feature, target):
    return feature - 128.0, target

def type_transform(feature, target):
    return tf.cast(feature, tf.float32), tf.cast(target, tf.float32)

# %%
# Train/val/test data
transforms = [type_transform, subtract_mean]
batch_size = 8
n_samples = 271
n_train_samples = int(0.8*n_samples)
n_val_samples = n_samples - n_train_samples

data = tf.data.TFRecordDataset('/home/jovyan/OSM_data/sanfranrgb.tfrecords') \
           .map(parse_example, num_parallel_calls=4)

# Apply transforms
for t in transforms:
    data = data.map(t, num_parallel_calls=4)

# Shuffle the data and split into train and validation set
data = data.shuffle(buffer_size=1000)
data_train = data.take(n_train_samples) \
                 .repeat() \
                 .batch(batch_size)
data_val = data.skip(n_train_samples) \
               .repeat() \
               .batch(batch_size)

# %%
# Carry out training
history = model.fit(data_train,
                    steps_per_epoch=n_train_samples//batch_size,
                    validation_data=data_val,
                    validation_steps=n_val_samples//batch_size,
                    epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 17s 626ms/step - loss: 25.0418 - accuracy: 0.5338 - val_loss: 9.2049 - val_accuracy: 0.5979
# Epoch 2/100
# 27/27 [==============================] - 16s 593ms/step - loss: 7.7019 - accuracy: 0.5821 - val_loss: 6.1701 - val_accuracy: 0.5980
# Epoch 3/100
# 27/27 [==============================] - 16s 600ms/step - loss: 5.6135 - accuracy: 0.5837 - val_loss: 4.4583 - val_accuracy: 0.5849
# Epoch 4/100
# 27/27 [==============================] - 17s 611ms/step - loss: 4.1424 - accuracy: 0.6006 - val_loss: 3.7032 - val_accuracy: 0.6034
# Epoch 5/100
# 27/27 [==============================] - 16s 608ms/step - loss: 3.4926 - accuracy: 0.6029 - val_loss: 3.2128 - val_accuracy: 0.6230
# Epoch 6/100
# 27/27 [==============================] - 16s 596ms/step - loss: 2.9967 - accuracy: 0.6170 - val_loss: 2.7857 - val_accuracy: 0.6761
# Epoch 7/100
# 27/27 [==============================] - 16s 594ms/step - loss: 2.6869 - accuracy: 0.6186 - val_loss: 1.9725 - val_accuracy: 0.6726
# Epoch 8/100
# 27/27 [==============================] - 16s 603ms/step - loss: 2.4444 - accuracy: 0.6292 - val_loss: 2.0952 - val_accuracy: 0.6453
# Epoch 9/100
# 27/27 [==============================] - 16s 603ms/step - loss: 2.0672 - accuracy: 0.6505 - val_loss: 2.0645 - val_accuracy: 0.6373
# Epoch 10/100
# 27/27 [==============================] - 16s 596ms/step - loss: 1.6058 - accuracy: 0.6969 - val_loss: 1.4415 - val_accuracy: 0.7298
# Epoch 11/100
# 27/27 [==============================] - 16s 596ms/step - loss: 1.4641 - accuracy: 0.7143 - val_loss: 1.2466 - val_accuracy: 0.7514
# Epoch 12/100
# 27/27 [==============================] - 16s 593ms/step - loss: 1.2860 - accuracy: 0.7382 - val_loss: 1.3277 - val_accuracy: 0.7334
# Epoch 13/100
# 27/27 [==============================] - 16s 593ms/step - loss: 1.0726 - accuracy: 0.7713 - val_loss: 1.1371 - val_accuracy: 0.7587
# Epoch 14/100
# 27/27 [==============================] - 16s 591ms/step - loss: 0.9761 - accuracy: 0.7838 - val_loss: 1.0094 - val_accuracy: 0.7847
# Epoch 15/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.9059 - accuracy: 0.7954 - val_loss: 0.8627 - val_accuracy: 0.7912
# Epoch 16/100
# 27/27 [==============================] - 16s 589ms/step - loss: 0.8422 - accuracy: 0.8048 - val_loss: 0.7656 - val_accuracy: 0.8085
# Epoch 17/100
# 27/27 [==============================] - 16s 586ms/step - loss: 0.7349 - accuracy: 0.8225 - val_loss: 0.6817 - val_accuracy: 0.8265
# Epoch 18/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.6779 - accuracy: 0.8300 - val_loss: 0.6981 - val_accuracy: 0.8355
# Epoch 19/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.6581 - accuracy: 0.8344 - val_loss: 0.5623 - val_accuracy: 0.8549
# Epoch 20/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.5933 - accuracy: 0.8457 - val_loss: 0.5708 - val_accuracy: 0.8592
# Epoch 21/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.5616 - accuracy: 0.8495 - val_loss: 0.5121 - val_accuracy: 0.8609
# Epoch 22/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.5334 - accuracy: 0.8566 - val_loss: 0.5621 - val_accuracy: 0.8467
# Epoch 23/100
# 27/27 [==============================] - 16s 590ms/step - loss: 0.5228 - accuracy: 0.8585 - val_loss: 0.4986 - val_accuracy: 0.8574
# Epoch 24/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.4284 - accuracy: 0.8755 - val_loss: 0.3773 - val_accuracy: 0.8886
# Epoch 25/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.4188 - accuracy: 0.8804 - val_loss: 0.4173 - val_accuracy: 0.8785
# Epoch 26/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.4417 - accuracy: 0.8739 - val_loss: 0.3876 - val_accuracy: 0.8847
# Epoch 27/100
# 27/27 [==============================] - 16s 608ms/step - loss: 0.3678 - accuracy: 0.8893 - val_loss: 0.4098 - val_accuracy: 0.8911
# Epoch 28/100
# 27/27 [==============================] - 16s 592ms/step - loss: 0.3629 - accuracy: 0.8923 - val_loss: 0.2942 - val_accuracy: 0.9063
# Epoch 29/100
# 27/27 [==============================] - 16s 599ms/step - loss: 0.3156 - accuracy: 0.9011 - val_loss: 0.3170 - val_accuracy: 0.9007
# Epoch 30/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.2967 - accuracy: 0.9060 - val_loss: 0.2823 - val_accuracy: 0.9092
# Epoch 31/100
# 27/27 [==============================] - 16s 605ms/step - loss: 0.2734 - accuracy: 0.9109 - val_loss: 0.2528 - val_accuracy: 0.9181
# Epoch 32/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.2555 - accuracy: 0.9169 - val_loss: 0.2308 - val_accuracy: 0.9205
# Epoch 33/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.2434 - accuracy: 0.9200 - val_loss: 0.2337 - val_accuracy: 0.9219
# Epoch 34/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.2276 - accuracy: 0.9244 - val_loss: 0.2420 - val_accuracy: 0.9159
# Epoch 35/100
# 27/27 [==============================] - 16s 589ms/step - loss: 0.2251 - accuracy: 0.9240 - val_loss: 0.1865 - val_accuracy: 0.9379
# Epoch 36/100
# 27/27 [==============================] - 16s 589ms/step - loss: 0.2874 - accuracy: 0.9122 - val_loss: 0.4523 - val_accuracy: 0.8656
# Epoch 37/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.3538 - accuracy: 0.8952 - val_loss: 0.3254 - val_accuracy: 0.9013
# Epoch 38/100
# 27/27 [==============================] - 16s 592ms/step - loss: 0.2601 - accuracy: 0.9133 - val_loss: 0.1905 - val_accuracy: 0.9364
# Epoch 39/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.2004 - accuracy: 0.9322 - val_loss: 0.1882 - val_accuracy: 0.9345
# Epoch 40/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1728 - accuracy: 0.9404 - val_loss: 0.1828 - val_accuracy: 0.9381
# Epoch 41/100
# 27/27 [==============================] - 16s 599ms/step - loss: 0.1899 - accuracy: 0.9390 - val_loss: 0.1697 - val_accuracy: 0.9418
# Epoch 42/100
# 27/27 [==============================] - 16s 599ms/step - loss: 0.1774 - accuracy: 0.9382 - val_loss: 0.1730 - val_accuracy: 0.9396
# Epoch 43/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1830 - accuracy: 0.9393 - val_loss: 0.1683 - val_accuracy: 0.9406
# Epoch 44/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.1706 - accuracy: 0.9411 - val_loss: 0.1412 - val_accuracy: 0.9501
# Epoch 45/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.1655 - accuracy: 0.9427 - val_loss: 0.1548 - val_accuracy: 0.9458
# Epoch 46/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.1420 - accuracy: 0.9498 - val_loss: 0.1434 - val_accuracy: 0.9495
# Epoch 47/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1626 - accuracy: 0.9478 - val_loss: 0.1554 - val_accuracy: 0.9398
# Epoch 48/100
# 27/27 [==============================] - 16s 608ms/step - loss: 0.2141 - accuracy: 0.9290 - val_loss: 0.3375 - val_accuracy: 0.8981
# Epoch 49/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1965 - accuracy: 0.9324 - val_loss: 0.1599 - val_accuracy: 0.9419
# Epoch 50/100
# 27/27 [==============================] - 16s 594ms/step - loss: 0.1557 - accuracy: 0.9481 - val_loss: 0.1165 - val_accuracy: 0.9584
# Epoch 51/100
# 27/27 [==============================] - 17s 619ms/step - loss: 0.1558 - accuracy: 0.9481 - val_loss: 0.1250 - val_accuracy: 0.9557
# Epoch 52/100
# 27/27 [==============================] - 17s 612ms/step - loss: 0.1108 - accuracy: 0.9609 - val_loss: 0.1020 - val_accuracy: 0.9640
# Epoch 53/100
# 27/27 [==============================] - 17s 611ms/step - loss: 0.1430 - accuracy: 0.9546 - val_loss: 0.1142 - val_accuracy: 0.9583
# Epoch 54/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.1069 - accuracy: 0.9614 - val_loss: 0.1206 - val_accuracy: 0.9587
# Epoch 55/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1008 - accuracy: 0.9645 - val_loss: 0.1054 - val_accuracy: 0.9643
# Epoch 56/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0930 - accuracy: 0.9673 - val_loss: 0.0942 - val_accuracy: 0.9681
# Epoch 57/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0850 - accuracy: 0.9706 - val_loss: 0.0825 - val_accuracy: 0.9720
# Epoch 58/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0864 - accuracy: 0.9704 - val_loss: 0.0822 - val_accuracy: 0.9707
# Epoch 59/100
# 27/27 [==============================] - 16s 608ms/step - loss: 0.0847 - accuracy: 0.9703 - val_loss: 0.0832 - val_accuracy: 0.9713
# Epoch 60/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0851 - accuracy: 0.9703 - val_loss: 0.1029 - val_accuracy: 0.9640
# Epoch 61/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1114 - accuracy: 0.9657 - val_loss: 0.0911 - val_accuracy: 0.9675
# Epoch 62/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1635 - accuracy: 0.9413 - val_loss: 0.1708 - val_accuracy: 0.9363
# Epoch 63/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1236 - accuracy: 0.9545 - val_loss: 0.0858 - val_accuracy: 0.9680
# Epoch 64/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.0834 - accuracy: 0.9696 - val_loss: 0.0817 - val_accuracy: 0.9719
# Epoch 65/100
# 27/27 [==============================] - 16s 594ms/step - loss: 0.1056 - accuracy: 0.9677 - val_loss: 0.1026 - val_accuracy: 0.9636
# Epoch 66/100
# 27/27 [==============================] - 16s 605ms/step - loss: 0.1042 - accuracy: 0.9604 - val_loss: 0.0668 - val_accuracy: 0.9752
# Epoch 67/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.0814 - accuracy: 0.9711 - val_loss: 0.0554 - val_accuracy: 0.9814
# Epoch 68/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.0712 - accuracy: 0.9759 - val_loss: 0.0544 - val_accuracy: 0.9816
# Epoch 69/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.1001 - accuracy: 0.9689 - val_loss: 0.0879 - val_accuracy: 0.9671
# Epoch 70/100
# 27/27 [==============================] - 16s 595ms/step - loss: 0.1013 - accuracy: 0.9682 - val_loss: 0.2274 - val_accuracy: 0.9528
# Epoch 71/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0828 - accuracy: 0.9690 - val_loss: 0.0648 - val_accuracy: 0.9769
# Epoch 72/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1011 - accuracy: 0.9682 - val_loss: 0.0862 - val_accuracy: 0.9683
# Epoch 73/100
# 27/27 [==============================] - 16s 598ms/step - loss: 0.0734 - accuracy: 0.9724 - val_loss: 0.0610 - val_accuracy: 0.9788
# Epoch 74/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1049 - accuracy: 0.9659 - val_loss: 0.1014 - val_accuracy: 0.9623
# Epoch 75/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.0732 - accuracy: 0.9731 - val_loss: 0.0742 - val_accuracy: 0.9766
# Epoch 76/100
# 27/27 [==============================] - 16s 605ms/step - loss: 0.0572 - accuracy: 0.9808 - val_loss: 0.0522 - val_accuracy: 0.9839
# Epoch 77/100
# 27/27 [==============================] - 18s 649ms/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.0486 - val_accuracy: 0.9845
# Epoch 78/100
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0457 - accuracy: 0.9855 - val_loss: 0.0565 - val_accuracy: 0.9832
# Epoch 79/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.0412 - accuracy: 0.9876 - val_loss: 0.0412 - val_accuracy: 0.9889
# Epoch 80/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.0445 - accuracy: 0.9864 - val_loss: 0.0398 - val_accuracy: 0.9882
# Epoch 81/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.0446 - accuracy: 0.9856 - val_loss: 0.0494 - val_accuracy: 0.9808
# Epoch 82/100
# 27/27 [==============================] - 16s 611ms/step - loss: 0.0752 - accuracy: 0.9724 - val_loss: 0.2067 - val_accuracy: 0.9621
# Epoch 83/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.0785 - accuracy: 0.9716 - val_loss: 0.0575 - val_accuracy: 0.9783
# Epoch 84/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.0558 - accuracy: 0.9800 - val_loss: 0.0572 - val_accuracy: 0.9825
# Epoch 85/100
# 27/27 [==============================] - 16s 611ms/step - loss: 0.0485 - accuracy: 0.9842 - val_loss: 0.0414 - val_accuracy: 0.9874
# Epoch 86/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.0413 - accuracy: 0.9871 - val_loss: 0.0353 - val_accuracy: 0.9898
# Epoch 87/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0360 - accuracy: 0.9890 - val_loss: 0.0490 - val_accuracy: 0.9863
# Epoch 88/100
# 27/27 [==============================] - 17s 615ms/step - loss: 0.0893 - accuracy: 0.9738 - val_loss: 0.0682 - val_accuracy: 0.9734
# Epoch 89/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.0922 - accuracy: 0.9716 - val_loss: 0.0441 - val_accuracy: 0.9844
# Epoch 90/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.0412 - accuracy: 0.9865 - val_loss: 0.0527 - val_accuracy: 0.9851
# Epoch 91/100
# 27/27 [==============================] - 16s 605ms/step - loss: 0.0334 - accuracy: 0.9902 - val_loss: 0.0347 - val_accuracy: 0.9893
# Epoch 92/100
# 27/27 [==============================] - 16s 609ms/step - loss: 0.0338 - accuracy: 0.9901 - val_loss: 0.0250 - val_accuracy: 0.9939
# Epoch 93/100
# 27/27 [==============================] - 16s 599ms/step - loss: 0.0292 - accuracy: 0.9919 - val_loss: 0.0306 - val_accuracy: 0.9915
# Epoch 94/100
# 27/27 [==============================] - 16s 605ms/step - loss: 0.0295 - accuracy: 0.9919 - val_loss: 0.0292 - val_accuracy: 0.9919
# Epoch 95/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.0269 - accuracy: 0.9927 - val_loss: 0.0201 - val_accuracy: 0.9949
# Epoch 96/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0853 - accuracy: 0.9747 - val_loss: 0.0594 - val_accuracy: 0.9781
# Epoch 97/100
# 27/27 [==============================] - 18s 656ms/step - loss: 0.0845 - accuracy: 0.9744 - val_loss: 0.0519 - val_accuracy: 0.9815
# Epoch 98/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0476 - accuracy: 0.9834 - val_loss: 0.0504 - val_accuracy: 0.9824
# Epoch 99/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 0.0443 - val_accuracy: 0.9871
# Epoch 100/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.0320 - accuracy: 0.9906 - val_loss: 0.0304 - val_accuracy: 0.9909

# %%
# Save the model
tf.saved_model.save(model, '/home/jovyan/OSM_data/rgb_new')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c8bc750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c85bcd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c80d8d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c743450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c957f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c746cd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c74aa10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c74f550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c7532d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c753e50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c6f4790>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c6fa350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c6fae50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c6fdcd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c702a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c706650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c70b450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7fba3c70bd90>, because it is not built.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /home/jovyan/OSM_data/rgb_new/assets

# %%
key = "key1"
# !zip -r rgb_new.zip rgb_new
print('Upload model to Storage')
storage = dl.Storage()
storage.set_file(key, '/home/jovyan/OSM_data/rgb_new.zip')
#os.remove('/home/jovyan/OSM_data/rgb_new.zip')
# Out:
# 	zip warning: name not matched: rgb_new
#
# zip error: Nothing to do! (try: zip -r rgb_new.zip . -i rgb_new)
# Upload model to Storage
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-41b12fb7f035> in <module>
#       3 print('Upload model to Storage')
#       4 storage = dl.Storage()
# ----> 5 storage.set_file(key, '/home/jovyan/OSM_data/rgb_new.zip')
#       6 #os.remove('/home/jovyan/OSM_data/rgb_new.zip')
#
# /opt/conda/lib/python3.7/site-packages/descarteslabs/client/services/storage/storage.py in set_file(self, key, file_obj, storage_type)
#     225
#     226         if isinstance(file_obj, six.string_types):
# --> 227             with open(file_obj, "rb") as f:
#     228                 self._gcs_upload_service.session.put(rurl, data=f)
#     229         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/OSM_data/rgb_new.zip'

# %%
fig, ax = plt.subplots(1, 2,  figsize=(12, 5))
ax[0].plot(history.history['loss'], label='train')
ax[0].plot(history.history['val_loss'], label='val')
ax[1].plot(history.history['accuracy'], label='train')
ax[1].plot(history.history['val_accuracy'], label='val')

ax[0].set_title('model loss')
ax[1].set_title('model accuracy')
ax[0].set_xlabel('epoch')
ax[0].set_ylabel('loss')
ax[1].set_xlabel('epoch')
ax[1].set_ylabel('accuracy')
ax[0].legend(loc='upper right')

plt.show()

# %%
min(history.history['val_loss'])
# Out:
# 0.020118163898587227

# %% [markdown]
# ### 4 - Evaluate model on new area

# %%
def load_model_from_storage(storage_key):
    '''Load TF model from DL.Storage'''
    import tempfile
    from tensorflow.keras.models import load_model
    import descarteslabs as dl
    model_zip = tempfile.NamedTemporaryFile()
    model_dir = tempfile.TemporaryDirectory()
    dl.Storage().get_file(storage_key, model_zip.name)
    os.system('unzip {} -d {}'.format(model_zip.name, model_dir.name))
    model = load_model(os.path.join(model_dir.name, '/home/jovyan/OSM_data/rgb_new'))
    model_zip.close()
    model_dir.cleanup()
    
    return model

# %%
def get_image(dltile_key):
    tile = dl.scenes.DLTile.from_key(dltile_key)
    sc, ctx = dl.scenes.search(aoi=tile, products="sentinel-2:L1C", start_datetime='2021-01-06', end_datetime='2021-01-11')
    im = sc.mosaic(bands='red green blue', ctx=ctx, bands_axis=-1)
    ids = [scene.properties.id for scene in sc]
    acquired_datetime = sc[-1].properties.date.isoformat() # grab the acquired date from the last scene
    
    metadata = {
        'acquired_datetime': acquired_datetime,
        'ids': ids,
    }
    
    return im, metadata

# %%
def get_image_highres(dltile_key):
    tile = dl.scenes.DLTile.from_key(dltile_key)
    sc, ctx = dl.scenes.search(aoi=tile, products="usda:naip:rgbn:v1", start_datetime='2016-01-01', end_datetime='2018-01-01')
    im = sc.mosaic(bands='red green blue', ctx=ctx, bands_axis=-1)
    ids = [scene.properties.id for scene in sc]
    acquired_datetime = sc[-1].properties.date.isoformat() # grab the acquired date from the last scene
    
    metadata = {
        'acquired_datetime': acquired_datetime,
        'ids': ids,
    }
    
    return im, metadata

# %%
def predict_image(model,dltile_key):
    print("Predict on image for dltile {}".format(dltile_key))
    
    # load model
    #model = model#load_model_from_storage(storage_key)
    
    # get imagery
    im, meta = get_image(dltile_key)
    
    # add batch dimension
    im = np.expand_dims(im, axis=0).astype(np.float32)
    
    # pre-process
    im, _ = subtract_mean(im, None)
    
    # predict
    pred = model.predict(im)
    
    # post-process
    pred = np.clip(255 * pred.squeeze(), 0, 255).astype('uint8')
    
    return im, pred, meta

# %%
lat, lon = 37.7718, -122.4091
tile = dl.scenes.DLTile.from_latlon(lat, lon, resolution=10, tilesize=128, pad=0)

im, pred, meta = predict_image(model,tile.key)
# Out:
# Predict on image for dltile 128:0:10.0:10:40:3266

# %%
hr, _ = get_image_highres(tile.key)
hr = np.expand_dims(hr, axis=0).astype(np.float32)
hr, _ = subtract_mean(hr, None)

sent, _ = get_image(tile.key)
sent = np.expand_dims(sent, axis=0).astype(np.float32)
sent, _ = subtract_mean(sent, None)

fig, ax = plt.subplots(1,3, figsize=(15,6))
ax[0].imshow((hr.squeeze()+128).astype('uint8'))
ax[1].imshow((sent.squeeze()+128).astype('uint8'))
ax[2].imshow(pred.squeeze(), cmap='magma')
ax[0].set_title('NAIP high-res imagery')
ax[1].set_title('Sentinel unscaled RGB bands')
ax[2].set_title('Building segmentation from Sentinel bands')
# Out:
# Text(0.5, 1.0, 'Building segmentation from Sentinel bands')

# %%
# Visualise on map
m2 = wf.interactive.MapApp()
m2.center = (37.7718, -122.3991)
m2.zoom = 16
# geo_json = ipyleaflet.GeoJSON(data=fc,
#                    style={'color': 'red', 'fillOpacity': 0.8},
#                    hover_style={'fillOpacity': 0.5})
# m2.add_layer(geo_json)

img = wf.ImageCollection.from_id("sentinel-2:L1C",start_datetime='2021-01-06', end_datetime='2021-01-10').pick_bands("red green blue")
my_mosaic = img.max(axis='images')
my_mosaic.visualize('image', map=m2)

# Finally, visualize this AOI!
m2
# Out:
# `ipyleaflet` and/or `ipywidgets` Jupyter extensions are not installed! (or you're not in a Jupyter notebook.)
# To install for JupyterLab, run this in a cell:
#     !jupyter labextension install jupyter-leaflet @jupyter-widgets/jupyterlab-manager
# To install for plain Jupyter Notebook, run this in a cell:
#     !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Then, restart the kernel and refresh the webpage.
