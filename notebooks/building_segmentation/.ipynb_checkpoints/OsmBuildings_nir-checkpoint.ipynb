# %% [markdown]
# ## Train Classifier to recognise buildings from Sentinel NIR imagery
#
# ### 1 - Import and display training building footprints

# %%
# Import packages - Needs utils.py and unet.py in current directory
import IPython
import ipywidgets
import ipyleaflet
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import numpy as np
import random
import os
import tensorflow as tf

import descarteslabs as dl
import descarteslabs.workflows as wf
from descarteslabs.vectors import FeatureCollection, properties as p

from utils import make_ground_dataset_from_polygons, get_center_location
from unet import UNet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-720f1d088ca1> in <module>
#      16 from descarteslabs.vectors import FeatureCollection, properties as p
#      17
# ---> 18 from utils import make_ground_dataset_from_polygons, get_center_location
#      19 from unet import UNet
#
# ModuleNotFoundError: No module named 'utils'

# %%
# Import Geojson - to FeatureCollection?
datapath = "/home/jovyan/OSM_data/"
with open(datapath+"sanFranBuildings.geojson") as f:
    fc = json.load(f)
print('Number of buildings:', len(fc['features']))
# Out:
# Number of buildings: 5758

# %%
# Visualise on map
m1 = wf.interactive.MapApp()
m1.center = (37.7818, -122.3981)
m1.zoom = 14
geo_json = ipyleaflet.GeoJSON(data=fc,
                   style={'color': 'red', 'fillOpacity': 0.8},
                   hover_style={'fillOpacity': 0.5})
m1.add_layer(geo_json)

img = wf.ImageCollection.from_id("sentinel-2:L1C",start_datetime='2021-01-06', end_datetime='2021-01-10').pick_bands("nir")
my_mosaic = img.max(axis='images')
my_mosaic.visualize('image', map=m1)

# Finally, visualize this AOI!
m1
# Out:
# `ipyleaflet` and/or `ipywidgets` Jupyter extensions are not installed! (or you're not in a Jupyter notebook.)
# To install for JupyterLab, run this in a cell:
#     !jupyter labextension install jupyter-leaflet @jupyter-widgets/jupyterlab-manager
# To install for plain Jupyter Notebook, run this in a cell:
#     !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Then, restart the kernel and refresh the webpage.

# %% [markdown]
# ### 2 - Get corresponding imagery for building footprints

# %%
n_samples = make_ground_dataset_from_polygons(datapath+'sanFranBuildings.geojson',
                                              products='sentinel-2:L1C',
                                              bands=['nir'],
                                              resolution=10,
                                              tilesize=64,
                                              pad=0,
                                              start_datetime='2021-01-06',
                                              end_datetime='2021-01-11',
                                              out_file=datapath+'sanfrannir.tfrecords')
# Out:
# WARNING: Some exceptions were caught while getting dltiles-1s
# Caught exception for lat: 37.768981208975106 and lon: -122.42387479246015 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F847014DAD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.768981208975106 and lon: -122.42387479246015 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.768981208975106 and lon: -122.42387479246015 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.766675993600735 and lon: -122.41635458326375 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.766675993600735 and lon: -122.41635458326375 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.766675993600735 and lon: -122.41635458326375 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76665272281533 and lon: -122.4167795421318 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F84700C0CD0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.76665272281533 and lon: -122.4167795421318 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F847014F6D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.76665272281533 and lon: -122.4167795421318 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F8470048B50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.766482090591445 and lon: -122.41731405512883 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F84701039D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.766482090591445 and lon: -122.41731405512883 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F84700E0C50> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.766482090591445 and lon: -122.41731405512883 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F847014F3D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7834092112945 and lon: -122.42626697772278 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F84701A0890> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.7834092112945 and lon: -122.42626697772278 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78378495538543 and lon: -122.4268808666009 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78378495538543 and lon: -122.4268808666009 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.
0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.76818003224213 and lon: -122.42938350269633 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76818003224213 and lon: -122.42938350269633 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77012594999999 and lon: -122.42739905 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77012594999999 and lon: -122.42739905 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.77012594999999 and lon: -122.42739905 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76811558100214 and lon: -122.42931290680437 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76811558100214 and lon: -122.42931290680437 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.76811558100214 and lon: -122.42931290680437 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78601495422064 and lon: -122.40369392998166 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78601495422064 and lon: -122.40369392998166 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78601495422064 and lon: -122.40369392998166 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78174961858515 and lon: -122.40121127105752 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78174961858515 and lon: -122.40121127105752 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78174961858515 and lon: -122.40121127105752 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78678091117433 and lon: -122.39472936489115 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78678091117433 and lon: -122.39472936489115 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E25E30D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78325604976715 and lon: -122.39791462708394 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E2777490> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78543494938545 and lon: -122.4036731390952 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78543494938545 and lon: -122.4036731390952 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78543494938545 and lon: -122.4036731390952 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78161485 and lon: -122.4010435 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78161485 and lon: -122.4010435 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78161485 and lon: -122.4010435 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.775623043428965 and lon: -122.39934571276763 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.775623043428965 and lon: -122.39934571276763 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.775623043428965 and lon: -122.39934571276763 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78099399503138 and lon: -122.39505094652148 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78099399503138 and lon: -122.39505094652148 - [Errno 2] No such file or directory: 'tmp.tiff'
# Caught exception for lat: 37.78099399503138 and lon: -122.39505094652148 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E264C490> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78161464028479 and lon: -122.39471836168073 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E266E5D0> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78161464028479 and lon: -122.39471836168073 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E2775850> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78161464028479 and lon: -122.39471836168073 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F84700AC290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78113270119328 and lon: -122.39498619804567 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F8470111A90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78113270119328 and lon: -122.39498619804567 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E267ED90> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.78113270119328 and lon: -122.39498619804567 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E260B350> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.781722825961786 and lon: -122.39442863913693 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F82E2812690> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.781722825961786 and lon: -122.39442863913693 - <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0x7F847017B290> has type TiffImageFile, but expected one of: int, long, float
# Caught exception for lat: 37.781722825961786 and lon: -122.39442863913693 - [Errno 2] No such file or directory: 'tmp.tiff'

# %%
# Define the features in the TFRecords file
features = {
    'image/image_data': tf.io.FixedLenSequenceFeature([], dtype=tf.float32, allow_missing=True),
    'image/height': tf.io.FixedLenFeature([], tf.int64),
    'image/width': tf.io.FixedLenFeature([], tf.int64),
    'image/channels': tf.io.FixedLenFeature([], tf.int64),
    'target/target_data': tf.io.FixedLenSequenceFeature([], dtype=tf.float32, allow_missing=True),
    'target/height': tf.io.FixedLenFeature([], tf.int64),
    'target/width': tf.io.FixedLenFeature([], tf.int64),
    'target/channels': tf.io.FixedLenFeature([], tf.int64),
    'dltile': tf.io.FixedLenFeature([], tf.string)
}

# %%
def parse_example(example_proto):
    image_features = tf.io.parse_single_example(example_proto, features)
    
    img_height = tf.cast(image_features['image/height'], tf.int32)
    img_width = tf.cast(image_features['image/width'], tf.int32)
    img_channels = tf.cast(image_features['image/channels'], tf.int32)
    
    target_height = tf.cast(image_features['target/height'], tf.int32)
    target_width = tf.cast(image_features['target/width'], tf.int32)
    target_channels = tf.cast(image_features['target/channels'], tf.int32)
    
    image_raw = tf.reshape(tf.squeeze(image_features['image/image_data']),
                           tf.stack([img_height, img_width, img_channels]))
    
    target_raw = tf.reshape(tf.squeeze(image_features['target/target_data']),
                            tf.stack([target_height, target_width, target_channels]))
    
    return image_raw, target_raw

# %%
# Create a TFRecordDataset to read images from these TFRecords
data = tf.data.TFRecordDataset(datapath+'sanfrannir.tfrecords') \
           .map(parse_example, num_parallel_calls=4)

data_viz = iter(data.batch(1))

# %%
# Visualize samples. You can re-run this cell to iterate through the dataset.
img, trg = next(data_viz)
fig, ax = plt.subplots(1,2, figsize=(8,5))
ax[0].imshow(img.numpy().astype(np.uint8)[0])
ax[1].imshow(trg.numpy().astype(np.uint8)[0].squeeze())

# %% [markdown]
# ### 3 - Train Classifier

# %%
# Build the model. We could just use the base_model but then the input size would be fixed
# once we load a saved model. In order to be able to predict on larger tiles we create an
# input layer with no fixed size
base_model = UNet()
inputs = tf.keras.layers.Input(shape=(None, None, 3))
model = tf.keras.Model(inputs=inputs, outputs=base_model(inputs))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# u_net_2 (UNet)               (None, None, None, 1)     7760097
# =================================================================
# Total params: 7,760,097
# Trainable params: 7,760,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define some transforms
def subtract_mean(feature, target):
    return feature - 128.0, target

def type_transform(feature, target):
    return tf.cast(feature, tf.float32), tf.cast(target, tf.float32)

# %%
transforms = [type_transform, subtract_mean]
batch_size = 8
n_samples = 271
n_train_samples = int(0.8*n_samples)
n_val_samples = n_samples - n_train_samples

data = tf.data.TFRecordDataset(datapath+'sanfrannir.tfrecords') \
           .map(parse_example, num_parallel_calls=4)

# Apply transforms
for t in transforms:
    data = data.map(t, num_parallel_calls=4)

# Shuffle the data and split into train and validation set
data = data.shuffle(buffer_size=1000)
data_train = data.take(n_train_samples) \
                 .repeat() \
                 .batch(batch_size)
data_val = data.skip(n_train_samples) \
               .repeat() \
               .batch(batch_size)

# %%
history = model.fit(data_train,
                    steps_per_epoch=n_train_samples//batch_size,
                    validation_data=data_val,
                    validation_steps=n_val_samples//batch_size,
                    epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 17s 627ms/step - loss: 13.0773 - accuracy: 0.5276 - val_loss: 8.0071 - val_accuracy: 0.5502
# Epoch 2/100
# 27/27 [==============================] - 16s 605ms/step - loss: 7.1137 - accuracy: 0.5578 - val_loss: 5.9014 - val_accuracy: 0.5717
# Epoch 3/100
# 27/27 [==============================] - 16s 600ms/step - loss: 5.0815 - accuracy: 0.5808 - val_loss: 4.5515 - val_accuracy: 0.5845
# Epoch 4/100
# 27/27 [==============================] - 16s 592ms/step - loss: 4.1558 - accuracy: 0.5954 - val_loss: 4.0929 - val_accuracy: 0.5983
# Epoch 5/100
# 27/27 [==============================] - 16s 592ms/step - loss: 3.7541 - accuracy: 0.5980 - val_loss: 3.2370 - val_accuracy: 0.6133
# Epoch 6/100
# 27/27 [==============================] - 16s 596ms/step - loss: 3.0317 - accuracy: 0.6269 - val_loss: 2.9127 - val_accuracy: 0.6223
# Epoch 7/100
# 27/27 [==============================] - 16s 594ms/step - loss: 2.4868 - accuracy: 0.6692 - val_loss: 1.9764 - val_accuracy: 0.7154
# Epoch 8/100
# 27/27 [==============================] - 17s 617ms/step - loss: 2.0552 - accuracy: 0.7154 - val_loss: 2.0684 - val_accuracy: 0.6946
# Epoch 9/100
# 27/27 [==============================] - 17s 612ms/step - loss: 1.7142 - accuracy: 0.7454 - val_loss: 1.6788 - val_accuracy: 0.7286
# Epoch 10/100
# 27/27 [==============================] - 16s 600ms/step - loss: 1.4151 - accuracy: 0.7765 - val_loss: 1.3284 - val_accuracy: 0.7898
# Epoch 11/100
# 27/27 [==============================] - 16s 597ms/step - loss: 1.3529 - accuracy: 0.7823 - val_loss: 1.1806 - val_accuracy: 0.7909
# Epoch 12/100
# 27/27 [==============================] - 16s 600ms/step - loss: 1.1123 - accuracy: 0.8063 - val_loss: 1.0913 - val_accuracy: 0.8084
# Epoch 13/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.9134 - accuracy: 0.8334 - val_loss: 0.7807 - val_accuracy: 0.8567
# Epoch 14/100
# 27/27 [==============================] - 16s 606ms/step - loss: 0.7851 - accuracy: 0.8495 - val_loss: 0.7024 - val_accuracy: 0.8614
# Epoch 15/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.8777 - accuracy: 0.8380 - val_loss: 0.7428 - val_accuracy: 0.8631
# Epoch 16/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.6940 - accuracy: 0.8603 - val_loss: 0.6149 - val_accuracy: 0.8711
# Epoch 17/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.5893 - accuracy: 0.8770 - val_loss: 0.5694 - val_accuracy: 0.8749
# Epoch 18/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.5147 - accuracy: 0.8888 - val_loss: 0.5538 - val_accuracy: 0.8790
# Epoch 19/100
# 27/27 [==============================] - 16s 611ms/step - loss: 0.4835 - accuracy: 0.8937 - val_loss: 0.4283 - val_accuracy: 0.9012
# Epoch 20/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.6071 - accuracy: 0.8735 - val_loss: 0.4505 - val_accuracy: 0.8922
# Epoch 21/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.4735 - accuracy: 0.8936 - val_loss: 0.4512 - val_accuracy: 0.8922
# Epoch 22/100
# 27/27 [==============================] - 16s 610ms/step - loss: 0.5323 - accuracy: 0.8836 - val_loss: 0.5035 - val_accuracy: 0.8795
# Epoch 23/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.3963 - accuracy: 0.9051 - val_loss: 0.3986 - val_accuracy: 0.9013
# Epoch 24/100
# 27/27 [==============================] - 17s 615ms/step - loss: 0.3552 - accuracy: 0.9123 - val_loss: 0.3044 - val_accuracy: 0.9223
# Epoch 25/100
# 27/27 [==============================] - 17s 638ms/step - loss: 0.3692 - accuracy: 0.9125 - val_loss: 0.4041 - val_accuracy: 0.8998
# Epoch 26/100
# 27/27 [==============================] - 17s 629ms/step - loss: 0.3861 - accuracy: 0.9084 - val_loss: 0.3322 - val_accuracy: 0.9140
# Epoch 27/100
# 27/27 [==============================] - 17s 622ms/step - loss: 0.3447 - accuracy: 0.9139 - val_loss: 0.2565 - val_accuracy: 0.9307
# Epoch 28/100
# 27/27 [==============================] - 17s 642ms/step - loss: 0.2836 - accuracy: 0.9237 - val_loss: 0.2512 - val_accuracy: 0.9307
# Epoch 29/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.2415 - accuracy: 0.9340 - val_loss: 0.2049 - val_accuracy: 0.9409
# Epoch 30/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.2452 - accuracy: 0.9340 - val_loss: 0.1977 - val_accuracy: 0.9432
# Epoch 31/100
# 27/27 [==============================] - 17s 644ms/step - loss: 0.2095 - accuracy: 0.9404 - val_loss: 0.2454 - val_accuracy: 0.9349
# Epoch 32/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0
100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.2023 - accuracy: 0.9514 - val_loss: 0.1629 - val_accuracy: 0.9471
# Epoch 57/100
# 27/27 [==============================] - 16s 592ms/step - loss: 0.1251 - accuracy: 0.9589 - val_loss: 0.0682 - val_accuracy: 0.9765
# Epoch 58/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0780 - accuracy: 0.9754 - val_loss: 0.0676 - val_accuracy: 0.9763
# Epoch 59/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0627 - accuracy: 0.9789 - val_loss: 0.0466 - val_accuracy: 0.9848
# Epoch 60/100
# 27/27 [==============================] - 16s 592ms/step - loss: 0.0440 - accuracy: 0.9864 - val_loss: 0.0334 - val_accuracy: 0.9907
# Epoch 61/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0366 - accuracy: 0.9891 - val_loss: 0.0399 - val_accuracy: 0.9876
# Epoch 62/100
# 27/27 [==============================] - 16s 611ms/step - loss: 0.0330 - accuracy: 0.9907 - val_loss: 0.0416 - val_accuracy: 0.9903
# Epoch 63/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.0327 - accuracy: 0.9904 - val_loss: 0.0425 - val_accuracy: 0.9878
# Epoch 64/100
# 27/27 [==============================] - 17s 616ms/step - loss: 0.0352 - accuracy: 0.9892 - val_loss: 0.0300 - val_accuracy: 0.9902
# Epoch 65/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0395 - accuracy: 0.9872 - val_loss: 0.0323 - val_accuracy: 0.9904
# Epoch 66/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0401 - accuracy: 0.9868 - val_loss: 0.2552 - val_accuracy: 0.9744
# Epoch 67/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0347 - accuracy: 0.9896 - val_loss: 0.0266 - val_accuracy: 0.9931
# Epoch 68/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.0237 - val_accuracy: 0.9925
# Epoch 69/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1119 - accuracy: 0.9786 - val_loss: 0.1668 - val_accuracy: 0.9468
# Epoch 70/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1332 - accuracy: 0.9562 - val_loss: 0.0863 - val_accuracy: 0.9700
# Epoch 71/100
# 27/27 [==============================] - 16s 599ms/step - loss: 0.0505 - accuracy: 0.9817 - val_loss: 0.0455 - val_accuracy: 0.9848
# Epoch 72/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0345 - accuracy: 0.9889 - val_loss: 0.0356 - val_accuracy: 0.9894
# Epoch 73/100
# 27/27 [==============================] - 16s 596ms/step - loss: 0.1363 - accuracy: 0.9678 - val_loss: 0.0752 - val_accuracy: 0.9731
# Epoch 74/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0561 - accuracy: 0.9806 - val_loss: 0.0557 - val_accuracy: 0.9798
# Epoch 75/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.1686 - accuracy: 0.9581 - val_loss: 0.1809 - val_accuracy: 0.9438
# Epoch 76/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.1802 - accuracy: 0.9528 - val_loss: 0.0756 - val_accuracy: 0.9736
# Epoch 77/100
# 27/27 [==============================] - 16s 597ms/step - loss: 0.0748 - accuracy: 0.9743 - val_loss: 0.0762 - val_accuracy: 0.9772
# Epoch 78/100
# 27/27 [==============================] - 16s 590ms/step - loss: 0.0572 - accuracy: 0.9803 - val_loss: 0.0418 - val_accuracy: 0.9876
# Epoch 79/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.1237 - accuracy: 0.9700 - val_loss: 0.0814 - val_accuracy: 0.9748
# Epoch 80/100
# 27/27 [==============================] - 16s 607ms/step - loss: 0.0439 - accuracy: 0.9851 - val_loss: 0.0275 - val_accuracy: 0.9915
# Epoch 81/100
# 27/27 [==============================] - 16s 598ms/step - loss: 0.0252 - accuracy: 0.9925 - val_loss: 0.0163 - val_accuracy: 0.9962
# Epoch 82/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.1001 - accuracy: 0.9751 - val_loss: 0.0845 - val_accuracy: 0.9703
# Epoch 83/100
# 27/27 [==============================] - 16s 608ms/step - loss: 0.0434 - accuracy: 0.9863 - val_loss: 0.0342 - val_accuracy: 0.9886
# Epoch 84/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.0284 - accuracy: 0.9923 - val_loss: 0.0223 - val_accuracy: 0.9931
# Epoch 85/100
# 27/27 [==============================] - 16s 592ms/step - loss: 0.0236 - accuracy: 0.9936 - val_loss: 0.0117 - val_accuracy: 0.9976
# Epoch 86/100
# 27/27 [==============================] - 16s 598ms/step - loss: 0.0175 - accuracy: 0.9954 - val_loss: 0.0109 - val_accuracy: 0.9980
# Epoch 87/100
# 27/27 [==============================] - 16s 590ms/step - loss: 0.0168 - accuracy: 0.9957 - val_loss: 0.0141 - val_accuracy: 0.9963
# Epoch 88/100
# 27/27 [==============================] - 16s 592ms/step - loss: 0.0133 - accuracy: 0.9971 - val_loss: 0.0158 - val_accuracy: 0.9960
# Epoch 89/100
# 27/27 [==============================] - 16s 595ms/step - loss: 0.0139 - accuracy: 0.9969 - val_loss: 0.0110 - val_accuracy: 0.9977
# Epoch 90/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0137 - accuracy: 0.9968 - val_loss: 0.0120 - val_accuracy: 0.9975
# Epoch 91/100
# 27/27 [==============================] - 16s 593ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.0145 - val_accuracy: 0.9963
# Epoch 92/100
# 27/27 [==============================] - 16s 603ms/step - loss: 0.0142 - accuracy: 0.9966 - val_loss: 0.0085 - val_accuracy: 0.9985
# Epoch 93/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0152 - accuracy: 0.9967 - val_loss: 0.0113 - val_accuracy: 0.9973
# Epoch 94/100
# 27/27 [==============================] - 16s 611ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0109 - val_accuracy: 0.9976
# Epoch 95/100
# 27/27 [==============================] - 16s 604ms/step - loss: 0.0138 - accuracy: 0.9967 - val_loss: 0.0129 - val_accuracy: 0.9970
# Epoch 96/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.0160 - accuracy: 0.9962 - val_loss: 0.0106 - val_accuracy: 0.9978
# Epoch 97/100
# 27/27 [==============================] - 16s 600ms/step - loss: 0.0118 - accuracy: 0.9973 - val_loss: 0.0117 - val_accuracy: 0.9974
# Epoch 98/100
# 27/27 [==============================] - 16s 601ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.0225 - val_accuracy: 0.9951
# Epoch 99/100
# 27/27 [==============================] - 16s 589ms/step - loss: 0.0130 - accuracy: 0.9969 - val_loss: 0.0140 - val_accuracy: 0.9966
# Epoch 100/100
# 27/27 [==============================] - 16s 599ms/step - loss: 0.0133 - accuracy: 0.9968 - val_loss: 0.0157 - val_accuracy: 0.9961

# %%
# Save the model
tf.saved_model.save(model, datapath+'nir_model_data/')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2be3d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2befd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2bde50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2baad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f82e2c71bd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f841aca1810>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2b0fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2adc50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f282a50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2876d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2ed1d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2e6a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2ede10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2efb90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2f4750>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2fbfd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2f4850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x7f833f2c4d90>, because it is not built.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nir_model_data/assets

# %%
# !zip -r nir_model_data.zip nir_model_data
print('Upload model to Storage')
storage = dl.Storage()
storage.set_file(datapath+'sanfrannir_demo', datapath+'nir_model_data.zip')
os.remove(datapath+'nir_model_data.zip')
# Out:
#   adding: nir_model_data/ (stored 0%)
#   adding: nir_model_data/saved_model.pb (deflated 92%)
#   adding: nir_model_data/variables/ (stored 0%)
#   adding: nir_model_data/variables/variables.index (deflated 75%)
#   adding: nir_model_data/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: nir_model_data/assets/ (stored 0%)
# Upload model to Storage

# %%
fig, ax = plt.subplots(1, 2,  figsize=(12, 5))
ax[0].plot(history.history['loss'], label='train')
ax[0].plot(history.history['val_loss'], label='val')
ax[1].plot(history.history['accuracy'], label='train')
ax[1].plot(history.history['val_accuracy'], label='val')

ax[0].set_title('model loss')
ax[1].set_title('model accuracy')
ax[0].set_xlabel('epoch')
ax[0].set_ylabel('loss')
ax[1].set_xlabel('epoch')
ax[1].set_ylabel('accuracy')
ax[0].legend(loc='upper right')

plt.show()

# %%
min(history.history['val_loss'])
# Out:
# 0.008506149053573608

# %% [markdown]
# ### 4 - Evaluate model on new area

# %%
def load_model_from_storage(storage_key):
    '''Load TF model from DL.Storage'''
    import tempfile
    from tensorflow.keras.models import load_model
    import descarteslabs as dl
    model_zip = tempfile.NamedTemporaryFile()
    model_dir = tempfile.TemporaryDirectory()
    dl.Storage().get_file(storage_key, model_zip.name)
    os.system('unzip {} -d {}'.format(model_zip.name, model_dir.name))
    model = load_model(os.path.join(model_dir.name, datapath+'nir_model_data'))
    model_zip.close()
    model_dir.cleanup()
    
    return model

# %%
def get_image_highres(dltile_key):
    tile = dl.scenes.DLTile.from_key(dltile_key)
    sc, ctx = dl.scenes.search(aoi=tile, products="usda:naip:rgbn:v1", start_datetime='2016-01-01', end_datetime='2018-01-01')
    im = sc.mosaic(bands='red green blue', ctx=ctx, bands_axis=-1)
    ids = [scene.properties.id for scene in sc]
    acquired_datetime = sc[-1].properties.date.isoformat() # grab the acquired date from the last scene
    
    metadata = {
        'acquired_datetime': acquired_datetime,
        'ids': ids,
    }
    
    return im, metadata

# %%
def get_image(dltile_key):
    tile = dl.scenes.DLTile.from_key(dltile_key)
    sc, ctx = dl.scenes.search(aoi=tile, products="sentinel-2:L1C", start_datetime='2021-01-06', end_datetime='2021-01-10')
    im = sc.mosaic(bands='nir nir nir', ctx=ctx, bands_axis=-1)
    ids = [scene.properties.id for scene in sc]
    acquired_datetime = sc[-1].properties.date.isoformat() # grab the acquired date from the last scene
    
    metadata = {
        'acquired_datetime': acquired_datetime,
        'ids': ids,
    }
    
    return im, metadata

# %%
def predict_image(dltile_key):
    print("Predict on image for dltile {}".format(dltile_key))
    
    # load model
    model = load_model_from_storage(datapath+'sanfrannir_demo')
    
    # get imagery
    im, meta = get_image(dltile_key)
    
    # add batch dimension
    im = np.expand_dims(im, axis=0).astype(np.float32)
    
    # pre-process
    im, _ = subtract_mean(im, None)
    
    # predict
    pred = model.predict(im)
    
    # post-process
    pred = np.clip(255 * pred.squeeze(), 0, 255).astype('uint8')
    
    return im, pred, meta

# %%
lat, lon = 37.7718, -122.4091
tile = dl.scenes.DLTile.from_latlon(lat, lon, resolution=10, tilesize=128, pad=0)

im, pred, meta = predict_image(tile.key)
# Out:
# Predict on image for dltile 128:0:10.0:10:40:3266
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8463071440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
hr, _ = get_image_highres(tile.key)
hr = np.expand_dims(hr, axis=0).astype(np.float32)
hr, _ = subtract_mean(hr, None)

fig, ax = plt.subplots(1,3, figsize=(15,6))
ax[0].imshow((hr.squeeze()+128).astype('uint8'))
ax[1].imshow((im.squeeze()+128).astype('uint8'))
ax[2].imshow(pred.squeeze(), cmap='magma')
