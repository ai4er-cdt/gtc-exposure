# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(tf.__version__)
print('GPUs available: {}'.format(len(tf.config.list_physical_devices('GPU'))))
# Out:
# 2.2.0
# GPUs available: 1

# %%
images_dir = 'data/Images/'
out_dir = 'data/UCM_preprocessed.tfrecords'

# %%
def open_image(image_loc, expected_dim):
    pixel_data = np.array(Image.open(image_loc).getdata())
    
    width = np.sqrt(pixel_data.shape[0])
    channels = pixel_data.shape[1]

    if width % 1 != 0:
        print('Image {} is not square, returning empty variable'.format(image_loc))
        return None
    
    if width != expected_dim:
        print('Image {} has dimension {}, expected {}, returning empty variable'.format(image_loc, width, expected_dim))
        return None
    
    width = int(width)
    
    return pixel_data.reshape((width, width, channels)) / 255.0 #Normalised

def _int64_feature(value):
    """Wrapper for inserting int64 features into Example proto."""
    if isinstance(value, np.ndarray):
        value = value.flatten().tolist()
    elif not isinstance(value, list):
        value = [value]
    return tf.train.Feature(int64_list=tf.train.Int64List(value=value))


def _float64_feature(value):
    """Wrapper for inserting float64 features into Example proto."""
    if isinstance(value, np.ndarray):
        value = value.flatten().tolist()
    elif not isinstance(value, list):
        value = [value]
    return tf.train.Feature(float_list=tf.train.FloatList(value=value))


def _bytes_feature(value):
    """Wrapper for inserting bytes features into Example proto."""
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def ucm_to_tfrecord_preprocessed(directory, out_file, datagen_args, expected_dim = 256, datagen_seed = 0, img_resize=None):
    if os.path.exists(out_file):
        os.remove(out_file)
    
    writer = tf.io.TFRecordWriter(out_file)
    
    label_dict = {}
    
    x = []
    y = []
    
    for label_int, label in enumerate(os.listdir(directory)):
        label_dict[label_int] = label
        for image_file in os.listdir("{}{}/".format(directory, label)):
            image_loc = "{}{}/{}".format(directory, label, image_file)
            
            image_data = open_image(image_loc, expected_dim)
                 
            if image_data is None:
                print("Image {} discarded".format(image_loc))
                continue
                
            x.append(image_data)
            y.append(label_int)
        
    shapes = {arr.shape for arr in x}
    print(shapes)
    x = np.stack(x)
    
    if not(img_resize is None):
        x = tf.image.resize(x, img_resize)
    
    y = np.stack(y)
    
    datagen = ImageDataGenerator(**datagen_args)
    print('Fitting')
    datagen.fit(x, seed = datagen_seed)
    print('Fitted')
    
    transform_iterator = datagen.flow(x, y, batch_size=1) #save_to_dir='tmp'
    
    i=0
    while i < x.shape[0]:
        xi, yi = next(transform_iterator)
        xi, yi = xi[0], yi[0]
        
        
        height = xi.shape[0]
        width = xi.shape[1]
        assert height == width

        channels = xi.shape[2]


        example = tf.train.Example(features=tf.train.Features(feature={
            'height': _int64_feature(height),
            'width': _int64_feature(width),
            'channels': _int64_feature(channels),
            'label': _int64_feature(yi),
            'image_raw': _float64_feature(xi)
        }))

        writer.write(example.SerializeToString())
        
        i+=1

    with open('data/label_dict_preprocessed.pkl', 'wb') as f:
        pkl.dump(label_dict, f, pkl.HIGHEST_PROTOCOL)

# %%
datagen_args = dict(
    featurewise_center=True, samplewise_center=False,
    featurewise_std_normalization=False, samplewise_std_normalization=False,
    zca_whitening=True, zca_epsilon=0.1, rotation_range=0, width_shift_range=0.0,
    height_shift_range=0.0, brightness_range=None, shear_range=0.0, zoom_range=0.0,
    channel_shift_range=0.0, fill_mode='nearest', cval=0.0,
    horizontal_flip=False, vertical_flip=False, rescale=None,
    preprocessing_function=None, data_format=None, validation_split=0.0, dtype=None
    )

# %%
# %%time
ucm_to_tfrecord_preprocessed(images_dir, out_dir, datagen_args, img_resize=(16,16))
# Out:
# Image data/Images/intersection/intersection99.tif is not square, returning empty variable
# Image data/Images/intersection/intersection99.tif discarded
# Image data/Images/storagetanks/storagetanks62.tif is not square, returning empty variable
# Image data/Images/storagetanks/storagetanks62.tif discarded
# Image data/Images/storagetanks/storagetanks60.tif is not square, returning empty variable
# Image data/Images/storagetanks/storagetanks60.tif discarded
# Image data/Images/storagetanks/storagetanks63.tif is not square, returning empty variable
# Image data/Images/storagetanks/storagetanks63.tif discarded
# Image data/Images/airplane/airplane55.tif is not square, returning empty variable
# Image data/Images/airplane/airplane55.tif discarded
# Image data/Images/airplane/airplane59.tif is not square, returning empty variable
# Image data/Images/airplane/airplane59.tif discarded
# Image data/Images/airplane/airplane76.tif is not square, returning empty variable
# Image data/Images/airplane/airplane76.tif discarded
# Image data/Images/parkinglot/parkinglot09.tif is not square, returning empty variable
# Image data/Images/parkinglot/parkinglot09.tif discarded
# Image data/Images/parkinglot/parkinglot20.tif is not square, returning empty variable
# Image data/Images/parkinglot/parkinglot20.tif discarded
# Image data/Images/sparseresidential/sparseresidential46.tif is not square, returning empty variable
# Image data/Images/sparseresidential/sparseresidential46.tif discarded
# Image data/Images/sparseresidential/sparseresidential22.tif is not square, returning empty variable
# Image data/Images/sparseresidential/sparseresidential22.tif discarded
# Image data/Images/sparseresidential/sparseresidential45.tif is not square, returning empty variable
# Image data/Images/sparseresidential/sparseresidential45.tif discarded
# Image data/Images/golfcourse/golfcourse04.tif is not square, returning empty variable
# Image data/Images/golfcourse/golfcourse04.tif discarded
# Image data/Images/golfcourse/golfcourse06.tif is not square, returning empty variable
# Image data/Images/golfcourse/golfcourse06.tif discarded
# Image data/Images/golfcourse/golfcourse07.tif is not square, returning empty variable
# Image data/Images/golfcourse/golfcourse07.tif discarded
# Image data/Images/golfcourse/golfcourse05.tif is not square, returning empty variable
# Image data/Images/golfcourse/golfcourse05.tif discarded
# Image data/Images/overpass/overpass66.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass66.tif discarded
# Image data/Images/overpass/overpass65.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass65.tif discarded
# Image data/Images/overpass/overpass64.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass64.tif discarded
# Image data/Images/overpass/overpass69.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass69.tif discarded
# Image data/Images/overpass/overpass62.tif is not square, returning empty variable
# Image data/Images/overpass/overpass62.tif discarded
# Image data/Images/overpass/overpass67.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass67.tif discarded
# Image data/Images/overpass/overpass59.tif is not square, returning empty variable
# Image data/Images/overpass/overpass59.tif discarded
# Image data/Images/overpass/overpass71.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass71.tif discarded
# Image data/Images/overpass/overpass68.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass68.tif discarded
# Image data/Images/overpass/overpass70.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/overpass/overpass70.tif discarded
# Image data/Images/tenniscourt/tenniscourt14.tif is not square, returning empty variable
# Image data/Images/tenniscourt/tenniscourt14.tif discarded
# Image data/Images/tenniscourt/tenniscourt36.tif is not square, returning empty variable
# Image data/Images/tenniscourt/tenniscourt36.tif discarded
# Image data/Images/harbor/harbor43.tif is not square, returning empty variable
# Image data/Images/harbor/harbor43.tif discarded
# Image data/Images/harbor/harbor10.tif has dimension 257.0, expected 256, returning empty variable
# Image data/Images/harbor/harbor10.tif discarded
# Image data/Images/beach/beach57.tif is not square, returning empty variable
# Image data/Images/beach/beach57.tif discarded
# Image data/Images/runway/runway88.tif is not square, returning empty variable
# Image data/Images/runway/runway88.tif discarded
# Image data/Images/runway/runway61.tif is not square, returning empty variable
# Image data/Images/runway/runway61.tif discarded
# Image data/Images/baseballdiamond/baseballdiamond93.tif is not square, returning empty variable
# Image data/Images/baseballdiamond/baseballdiamond93.tif discarded
# Image data/Images/baseballdiamond/baseballdiamond45.tif is not square, returning empty variable
# Image data/Images/baseballdiamond/baseballdiamond45.tif discarded
# Image data/Images/baseballdiamond/baseballdiamond15.tif is not square, returning empty variable
# Image data/Images/baseballdiamond/baseballdiamond15.tif discarded
# Image data/Images/baseballdiamond/baseballdiamond35.tif is not square, returning empty variable
# Image data/Images/baseballdiamond/baseballdiamond35.tif discarded
# Image data/Images/buildings/buildings96.tif has dimension 247.0, expected 256, returning empty variable
# Image data/Images/buildings/buildings96.tif discarded
# Image data/Images/mobilehomepark/mobilehomepark22.tif is not square, returning empty variable
# Image data/Images/mobilehomepark/mobilehomepark22.tif discarded
# Image data/Images/mobilehomepark/mobilehomepark23.tif is not square, returning empty variable
# Image data/Images/mobilehomepark/mobilehomepark23.tif discarded
# Image data/Images/mobilehomepark/mobilehomepark24.tif is not square, returning empty variable
# Image data/Images/mobilehomepark/mobilehomepark24.tif discarded
# Image data/Images/mobilehomepark/mobilehomepark33.tif is not square, returning empty variable
# Image data/Images/mobilehomepark/mobilehomepark33.tif discarded
# Image data/Images/river/river30.tif is not square, returning empty variable
# Image data/Images/river/river30.tif discarded
# Image data/Images/river/river83.tif is not square, returning empty variable
# Image data/Images/river/river83.tif discarded
# {(256, 256, 3)}
# Fitting
# Fitted
# CPU times: user 2min 10s, sys: 14 s, total: 2min 24s
# Wall time: 2min 6s
