# %%
import descarteslabs as dl
from shapely.geometry import Polygon, MultiPolygon
from gen_train_data import generate_sentinel_training_images

# %%
geometry = Polygon([[-77.11900972321072,18.40641275715119],
                    [-77.05223344757596,18.407064273107025],
                    [-77.04931520416775,18.350373169852766],
                    [-77.11660646393338,18.349558506762662],
                    [-77.11900972321072,18.40641275715119]])

# %%
images = generate_sentinel_training_images(geometry, 'Ocho_Rios',tile_size= 32)

# %%
dl.scenes.display(images[11], size=4)
